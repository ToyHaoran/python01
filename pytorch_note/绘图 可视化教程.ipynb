# %% [markdown]
# # 入门
# %matplotlib notebook 用于交互式绘图，但容易出问题
# %matplotlib 弹出式窗口，需要plt.show()
# %matplotlib inline 适合导出md格式，需要plt.show()
# %matplotlib auto 或 %matplotlib 显示动态图片(以弹出窗口的方式)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from pylab import *
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体，解决中文不显示的问题
mpl.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题

fig = plt.figure(figsize=(13, 13))
ax1 = fig.add_subplot(2, 2, 1)  # 图像应该是2×2的(即最多4张图)，且当前选中的是4个subplot中的第一个
plt.plot([1.5, 3.5, -2, 1.6], label="直线")  # 直线图 可接受一组x坐标和y坐标 (默认x坐标1234)

ax2 = fig.add_subplot(2, 2, 2)
plt.title("散点图")  # 可以ax2.xxx 但是没有提示；
plt.xlabel('X轴')
plt.ylabel("Y轴")
plt.scatter(np.arange(10), np.arange(10, 20), label="散点")
plt.legend(loc="best")  # 图例的位置

ax3 = fig.add_subplot(2, 2, 3)
plt.plot(np.arange(10), linestyle='--', color='g')  # 等价'g--' 可以指定'#CECECE'

# fig, axes = plt.subplots(2, 2)  # 与上面等价4个图，但可以对axes数组进行索引 如axes[0,0]
